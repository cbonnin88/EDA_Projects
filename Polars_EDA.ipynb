# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/EDA_Projects/blob/main/Polars_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import polars as pl
import numpy as np
import json
import random
from datetime import datetime, timedelta
import plotly.express as px

# %%
np.random.seed(42)
n_rows = 10000
user_ids = [f'u_{i}' for i in range(100,500)]
events = ['login','view_item','add_to_cart','checkout_start','purchase','error']

# %%
def dirty_price():
  val = round(random.uniform(10,500),2)
  if random.random() < 0.05: return f'€{val}'
  if random.random() < 0.05: return None
  return val

# %%
def generate_metadata():
  meta = {'browser': random.choice(['Chrome','Firefox','Safari']),
          'is_mobile': random.choice(['True','False'])}
  if random.random() < 0.1: return None
  return json.dumps(meta)

# %%
product_data = {
    'event_id': [f'evt_{i}' for i in range(n_rows)],
    'user_id': np.random.choice(user_ids + [None], n_rows),
    'event_name': np.random.choice(events, n_rows, p=[0.2,0.4,0.2,0.1,0.05,0.05]),
    'timestamp': [datetime(2024,1,1) + timedelta(minutes=random.randint(0,40000)) for _ in range(n_rows)],
    'price': [dirty_price() for _ in range(n_rows)],
    'metadata': [generate_metadata() for _ in range(n_rows)],
    'session_source': np.random.choice(['google','direct','meta','Google','META'], n_rows)
}

df_product = pd.DataFrame(product_data)

# %%
df_product = pd.concat([df_product,df_product.sample(200)])

# %%
df_product.to_csv('raw_product_data.csv', index=False)
print('Files ready: raw_product_data.csv')
# Out:
# Files ready: raw_product_data.csv

# %% [markdown]
# # **Data Cleaning**

# %%
# Lazy Evaluation (Scan)
q1 = (
    pl.scan_csv('raw_product_data.csv')
    .unique()
    .filter(pl.col('user_id').is_not_null())
    .with_columns([
        pl.col('price')
        .str.replace(r'€','')
        .cast(pl.Float64,strict=False)
        .alias('price_clean'),

        pl.col('timestamp').str.to_datetime()
    ])
    .with_columns(
        pl.col('metadata')
        .str.json_decode(pl.Struct({'browser':pl.String,'is_mobile':pl.String}))
        .alias('meta_struct')
    )
    .unnest('meta_struct')
    .with_columns(
        pl.when(pl.col('is_mobile') == 'True')
        .then(pl.lit(True))
        .otherwise(pl.lit(False))
        .alias('is_mobile')
    )
)

df_product_clean = q1.collect()
display(df_product_clean.head())
# Out:
# shape: (5, 10)
# ┌──────────┬─────────┬────────────┬────────────┬───┬────────────┬────────────┬─────────┬───────────┐
# │ event_id ┆ user_id ┆ event_name ┆ timestamp  ┆ … ┆ session_so ┆ price_clea ┆ browser ┆ is_mobile │
# │ ---      ┆ ---     ┆ ---        ┆ ---        ┆   ┆ urce       ┆ n          ┆ ---     ┆ ---       │
# │ str      ┆ str     ┆ str        ┆ datetime[μ ┆   ┆ ---        ┆ ---        ┆ str     ┆ bool      │
# │          ┆         ┆            ┆ s]         ┆   ┆ str        ┆ f64        ┆         ┆           │
# ╞══════════╪═════════╪════════════╪════════════╪═══╪════════════╪════════════╪═════════╪═══════════╡
# │ evt_9256 ┆ u_309   ┆ login      ┆ 2024-01-01 ┆ … ┆ direct     ┆ 73.39      ┆ Chrome  ┆ true      │
# │          ┆         ┆            ┆ 14:19:00   ┆   ┆            ┆            ┆         ┆           │
# │ evt_7479 ┆ u_173   ┆ view_item  ┆ 2024-01-13 ┆ … ┆ direct     ┆ 407.06     ┆ Firefox ┆ true      │
# │          ┆         ┆            ┆ 12:56:00   ┆   ┆            ┆            ┆         ┆           │
# │ evt_6423 ┆ u_250   ┆ view_item  ┆ 2024-01-17 ┆ … ┆ meta       ┆ 174.81     ┆ Safari  ┆ true      │
# │          ┆         ┆            ┆ 13:14:00   ┆   ┆            ┆            ┆         ┆           │
# │ evt_692  ┆ u_244   ┆ login      ┆ 2024-01-18 ┆ … ┆ Google     ┆ 288.64     ┆ Firefox ┆ false     │
# │          ┆         ┆            ┆ 14:07:00   ┆   ┆            ┆            ┆         ┆           │
# │ evt_2195 ┆ u_473   ┆ view_item  ┆ 2024-01-12 ┆ … ┆ google     ┆ 334.78     ┆ null    ┆ false     │
# │          ┆         ┆            ┆ 08:44:00   ┆   ┆            ┆            ┆         ┆           │
# └──────────┴─────────┴────────────┴────────────┴───┴────────────┴────────────┴─────────┴───────────┘

# %% [markdown]
# # **Metrics**

# %%
# Simple Funnel
funnel = (
    df_product_clean
    .filter(pl.col('event_name').is_in(['view_item','add_to_cart','purchase']))
    .group_by('event_name')
    .agg(pl.col('user_id').n_unique().alias('user_count'))
    .with_columns(
        pl.col('event_name')
        .replace_strict({'view_item': 1, 'add_to_cart':2, 'purchase':3}, default=99)
        .alias('step_order')
    )
    .sort('step_order')
)
display('Funnel:', funnel)
# Out:
# 'Funnel:'
# shape: (3, 3)
# ┌─────────────┬────────────┬────────────┐
# │ event_name  ┆ user_count ┆ step_order │
# │ ---         ┆ ---        ┆ ---        │
# │ str         ┆ u32        ┆ i64        │
# ╞═════════════╪════════════╪════════════╡
# │ view_item   ┆ 400        ┆ 1          │
# │ add_to_cart ┆ 396        ┆ 2          │
# │ purchase    ┆ 287        ┆ 3          │
# └─────────────┴────────────┴────────────┘

# %%
# AOV
aov = (
    df_product_clean
    .filter(pl.col('event_name')== 'purchase')
    .select(pl.col('price_clean').mean().round(0).alias('average_order_value'))
)
display('AOV:',aov)
# Out:
# 'AOV:'
# shape: (1, 1)
# ┌─────────────────────┐
# │ average_order_value │
# │ ---                 │
# │ f64                 │
# ╞═════════════════════╡
# │ 251.0               │
# └─────────────────────┘

# %%
# User Sessions
sessions = (
    df_product_clean
    .sort(['user_id','timestamp'])
    .with_columns([
        pl.col('timestamp').diff().over('user_id').alias('time_diff')
    ])
    .with_columns([
        pl.when((pl.col('time_diff').dt.total_seconds()> 1800) | (pl.col('time_diff').is_null()))
        .then(1)
        .otherwise(0)
        .alias('is_new_session')
    ])
    .with_columns([
        pl.col('is_new_session').cum_sum().alias('global_session_id')
    ])
)

display(sessions.select(['user_id','timestamp','is_new_session','global_session_id']).head(10))
# Out:
# shape: (10, 4)
# ┌─────────┬─────────────────────┬────────────────┬───────────────────┐
# │ user_id ┆ timestamp           ┆ is_new_session ┆ global_session_id │
# │ ---     ┆ ---                 ┆ ---            ┆ ---               │
# │ str     ┆ datetime[μs]        ┆ i32            ┆ i32               │
# ╞═════════╪═════════════════════╪════════════════╪═══════════════════╡
# │ u_100   ┆ 2024-01-01 03:44:00 ┆ 1              ┆ 1                 │
# │ u_100   ┆ 2024-01-02 01:44:00 ┆ 1              ┆ 2                 │
# │ u_100   ┆ 2024-01-02 16:07:00 ┆ 1              ┆ 3                 │
# │ u_100   ┆ 2024-01-03 11:19:00 ┆ 1              ┆ 4                 │
# │ u_100   ┆ 2024-01-03 22:26:00 ┆ 1              ┆ 5                 │
# │ u_100   ┆ 2024-01-05 07:53:00 ┆ 1              ┆ 6                 │
# │ u_100   ┆ 2024-01-06 05:30:00 ┆ 1              ┆ 7                 │
# │ u_100   ┆ 2024-01-06 20:16:00 ┆ 1              ┆ 8                 │
# │ u_100   ┆ 2024-01-08 16:09:00 ┆ 1              ┆ 9                 │
# │ u_100   ┆ 2024-01-09 18:43:00 ┆ 1              ┆ 10                │
# └─────────┴─────────────────────┴────────────────┴───────────────────┘

# %% [markdown]
# # **Plotly**

# %%
# Aggregate Session Metrics
# Grouping by the calculate 'global_session_id
session_metrics = (
    sessions
    .group_by(['user_id','global_session_id'])
    .agg([
        pl.col('timestamp').min().alias('session_start'),
        pl.col('timestamp').max().alias('session_end'),
        pl.col('event_name').count().alias('event_count')
    ])
    .with_columns(
        (pl.col('session_end') - pl.col('session_start')).dt.total_minutes().alias('duration_minutes')
    )
    .filter(pl.col('duration_minutes') > 0)
    .sort('session_start')
)

display(session_metrics.head())
# Out:
# shape: (5, 6)
# ┌─────────┬───────────────────┬───────────────┬──────────────┬─────────────┬──────────────────┐
# │ user_id ┆ global_session_id ┆ session_start ┆ session_end  ┆ event_count ┆ duration_minutes │
# │ ---     ┆ ---               ┆ ---           ┆ ---          ┆ ---         ┆ ---              │
# │ str     ┆ i32               ┆ datetime[μs]  ┆ datetime[μs] ┆ u32         ┆ i64              │
# ╞═════════╪═══════════════════╪═══════════════╪══════════════╪═════════════╪══════════════════╡
# │ u_314   ┆ 5258              ┆ 2024-01-01    ┆ 2024-01-01   ┆ 2           ┆ 17               │
# │         ┆                   ┆ 01:36:00      ┆ 01:53:00     ┆             ┆                  │
# │ u_382   ┆ 6883              ┆ 2024-01-01    ┆ 2024-01-01   ┆ 2           ┆ 22               │
# │         ┆                   ┆ 07:00:00      ┆ 07:22:00     ┆             ┆                  │
# │ u_120   ┆ 513               ┆ 2024-01-01    ┆ 2024-01-01   ┆ 2           ┆ 3                │
# │         ┆                   ┆ 09:19:00      ┆ 09:22:00     ┆             ┆                  │
# │ u_425   ┆ 7934              ┆ 2024-01-01    ┆ 2024-01-01   ┆ 2           ┆ 17               │
# │         ┆                   ┆ 11:18:00      ┆ 11:35:00     ┆             ┆                  │
# │ u_379   ┆ 6814              ┆ 2024-01-01    ┆ 2024-01-01   ┆ 2           ┆ 27               │
# │         ┆                   ┆ 18:48:00      ┆ 19:15:00     ┆             ┆                  │
# └─────────┴───────────────────┴───────────────┴──────────────┴─────────────┴──────────────────┘

# %%
# Converting to Pandas because Plotly works better with Pandas
plot_df = session_metrics.select('duration_minutes').to_pandas()

# %%
fig_sessions = px.histogram(
    plot_df,
    x='duration_minutes',
    nbins=50,
    title='Session Distribution Lengths',
    labels= {'duration_minutes': 'Session Duration (Minutes)'},
    template = 'plotly_white'
)

median_val = plot_df['duration_minutes'].median()
fig_sessions.add_vline(x=median_val,line_dash='dash',line_color='red',annotation_text=f'Median:{median_val:.1f}m')

fig_sessions.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="96312bfe-6f70-40cc-851e-068c3af9b836" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96312bfe-6f70-40cc-851e-068c3af9b836")) {                    Plotly.newPlot(                        "96312bfe-6f70-40cc-851e-068c3af9b836",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Session Duration (Minutes)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[17,22,3,17,27,11,29,30,27,11,6,9,6,8,26,3,2,11,20,9,22,18,20,21,13,19,17,23,11,9,6,17,3,23,20,20,18,21,7,9,9,20,13,18,18,27,19,16,5,10,15,29,6,4,11,8,24,23,14,7,9,2,23,15,16,6,19,27,22,7,10,19,13,4,1,8,8,3,5,24,26,15,13,24,11,30,11,7,15,11,8,27,7,28,9,5,26,13,24,27,23,28,21,30,5,4,44,26,10,5,13,10,8,19,34,4,20,24,1,25,22,14,7,5,6,16,9,9,7,29,15,30,8,16,16,6,7,24,27,29,11,7,11,1,11,16,7,28,28,21,15,25,11,5,23,13,28,28,18,20,18,20,11,16,17,18,2,29,60,30,3,2,17,25,3,7,18,18,7,14,13,13,24,2,18,20,9,5,2,18,9,29,27,16,16,15],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...

# %% [markdown]
# # **User Activity Gantt Chart**

# %%
# Filter for top 5 user so the chart is readable
top_users = (
    session_metrics
    .group_by('user_id')
    .agg(pl.count('global_session_id').alias('total_sessions'))
    .top_k(5, by='total_sessions')
    .select('user_id')
)

display(top_users)
# Out:
# shape: (5, 1)
# ┌─────────┐
# │ user_id │
# │ ---     │
# │ str     │
# ╞═════════╡
# │ u_210   │
# │ u_262   │
# │ u_336   │
# │ u_250   │
# │ u_461   │
# └─────────┘

# %%
timeline_df = (
    session_metrics
    .join(top_users, on='user_id',how='inner')
    .to_pandas()
)

display(timeline_df)
# Out:
#    user_id  global_session_id       session_start         session_end  \
# 0    u_210               2697 2024-01-02 05:02:00 2024-01-02 05:11:00
# 1    u_210               2702 2024-01-05 18:47:00 2024-01-05 18:56:00
# 2    u_336               5811 2024-01-07 18:36:00 2024-01-07 18:45:00
# 3    u_262               4001 2024-01-10 06:59:00 2024-01-10 07:08:00
# 4    u_250               3695 2024-01-10 21:09:00 2024-01-10 21:24:00
# 5    u_210               2706 2024-01-15 06:22:00 2024-01-15 06:30:00
# 6    u_262               4007 2024-01-18 14:56:00 2024-01-18 15:10:00
# 7    u_461               8801 2024-01-18 21:49:00 2024-01-18 21:54:00
# 8    u_461               8803 2024-01-20 09:09:00 2024-01-20 09:25:00
# 9    u_336               5835 2024-01-21 19:51:00 2024-01-21 20:19:00
# 10   u_262               4009 2024-01-22 19:12:00 2024-01-22 19:32:00
# 11   u_250               3707 2024-01-25 03:33:00 2024-01-25 03:46:00
#
#     event_count  duration_minutes
# 0             2                 9
# 1             2                 9
# 2             2                 9
# 3             2                 9
# 4             2                15
# 5             2                 8
# 6             2                14
# 7             2                 5
# 8             2                16
# 9             2                28
# 10            2                20
# 11            2                13

# %%
fig_timeline = px.timeline(
    timeline_df,
    x_start='session_start',
    x_end='session_end',
    y='user_id',
    color='event_count',
    title='User Session Timeline (Top 5 Users)',
    labels={'user_id':'User ID','event_count':'Events in Session'},
    template='plotly_white'
)

fig_timeline.update_yaxes(categoryorder='total ascending')

fig_timeline.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c1e20500-0bd7-444c-99ff-fa0a228fe779" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1e20500-0bd7-444c-99ff-fa0a228fe779")) {                    Plotly.newPlot(                        "c1e20500-0bd7-444c-99ff-fa0a228fe779",                        [{"alignmentgroup":"True","base":["2024-01-02T05:02:00","2024-01-05T18:47:00","2024-01-07T18:36:00","2024-01-10T06:59:00","2024-01-10T21:09:00","2024-01-15T06:22:00","2024-01-18T14:56:00","2024-01-18T21:49:00","2024-01-20T09:09:00","2024-01-21T19:51:00","2024-01-22T19:12:00","2024-01-25T03:33:00"],"hovertemplate":"Events in Session=2\u003cbr\u003esession_start=%{base}\u003cbr\u003esession_end=%{x}\u003cbr\u003eUser ID=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"h","showlegend":true,"textposition":"auto","x":[540000.0,540000.0,540000.0,540000.0,900000.0,480000.0,840000.0,300000.0,960000.0,1680000.0,1200000.0,780000.0],"xaxis":"x","y":["u_210","u_210","u_336","u_262","u_250","u_210","u_262","u_461","u_461","u_336","u_262","u_250"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %% [markdown]
# # **Time of Day Challenge**

# %%
tod_analytics = (
    session_metrics
    .with_columns(
        pl.col('session_start').dt.hour().alias('hour')
    )
    .with_columns(
        pl.when((pl.col('hour') >= 5) & (pl.col('hour') < 12))
        .then(pl.lit('Morning'))
        .when((pl.col('hour') >= 12) & (pl.col('hour') < 17))
        .then(pl.lit('Afternoon'))
        .when((pl.col('hour') >= 17) & (pl.col('hour') < 21))
        .then(pl.lit('Evening'))
        .otherwise(pl.lit('Night'))
        .alias('time_of_day')
    )
)

display(tod_analytics)
# Out:
# shape: (196, 8)
# ┌─────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┬──────┬────────────┐
# │ user_id ┆ global_sess ┆ session_sta ┆ session_end ┆ event_count ┆ duration_m ┆ hour ┆ time_of_da │
# │ ---     ┆ ion_id      ┆ rt          ┆ ---         ┆ ---         ┆ inutes     ┆ ---  ┆ y          │
# │ str     ┆ ---         ┆ ---         ┆ datetime[μs ┆ u32         ┆ ---        ┆ i8   ┆ ---        │
# │         ┆ i32         ┆ datetime[μs ┆ ]           ┆             ┆ i64        ┆      ┆ str        │
# │         ┆             ┆ ]           ┆             ┆             ┆            ┆      ┆            │
# ╞═════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╪══════╪════════════╡
# │ u_314   ┆ 5258        ┆ 2024-01-01  ┆ 2024-01-01  ┆ 2           ┆ 17         ┆ 1    ┆ Night      │
# │         ┆             ┆ 01:36:00    ┆ 01:53:00    ┆             ┆            ┆      ┆            │
# │ u_382   ┆ 6883        ┆ 2024-01-01  ┆ 2024-01-01  ┆ 2           ┆ 22         ┆ 7    ┆ Morning    │
# │         ┆             ┆ 07:00:00    ┆ 07:22:00    ┆             ┆            ┆      ┆            │
# │ u_120   ┆ 513         ┆ 2024-01-01  ┆ 2024-01-01  ┆ 2           ┆ 3          ┆ 9    ┆ Morning    │
# │         ┆             ┆ 09:19:00    ┆ 09:22:00    ┆             ┆            ┆      ┆            │
# │ u_425   ┆ 7934        ┆ 2024-01-01  ┆ 2024-01-01  ┆ 2           ┆ 17         ┆ 11   ┆ Morning    │
# │         ┆             ┆ 11:18:00    ┆ 11:35:00    ┆             ┆            ┆      ┆            │
# │ u_379   ┆ 6814        ┆ 2024-01-01  ┆ 2024-01-01  ┆ 2           ┆ 27         ┆ 18   ┆ Evening    │
# │         ┆             ┆ 18:48:00    ┆ 19:15:00    ┆             ┆            ┆      ┆            │
# │ …       ┆ …           ┆ …           ┆ …           ┆ …           ┆ …          ┆ …    ┆ …          │
# │ u_486   ┆ 9458        ┆ 2024-01-27  ┆ 2024-01-27  ┆ 2           ┆ 29         ┆ 5    ┆ Morning    │
# │         ┆             ┆ 05:48:00    ┆ 06:17:00    ┆             ┆            ┆      ┆            │
# │ u_228   ┆ 3164        ┆ 2024-01-27  ┆ 2024-01-27  ┆ 2           ┆ 27         ┆ 9    ┆ Morning    │
# │         ┆             ┆ 09:09:00    ┆ 09:36:00    ┆             ┆            ┆      ┆            │
# │ u_340   ┆ 5923        ┆ 2024-01-27  ┆ 2024-01-27  ┆ 2           ┆ 16         ┆ 22   ┆ Night      │
# │         ┆             ┆ 22:19:00    ┆ 22:35:00    ┆             ┆            ┆      ┆            │
# │ u_453   ┆ 8620        ┆ 2024-01-28  ┆ 2024-01-28  ┆ 2           ┆ 16         ┆ 11   ┆ Morning    │
# │         ┆             ┆ 11:01:00    ┆ 11:17:00    ┆             ┆            ┆      ┆            │
# │ u_346   ┆ 6064        ┆ 2024-01-28  ┆ 2024-01-28  ┆ 2           ┆ 15         ┆ 17   ┆ Evening    │
# │         ┆             ┆ 17:01:00    ┆ 17:16:00    ┆             ┆            ┆      ┆            │
# └─────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┴──────┴────────────┘

# %%
tod_stats = (
    tod_analytics
    .group_by('time_of_day')
    .agg([
        pl.col('duration_minutes').median().alias('median_duration'),
        pl.col('duration_minutes').count().alias('session_count')
    ])
    .with_columns(
        pl.col('time_of_day')
        .replace_strict({'Morning':1,'Afternoon':2,'Evening':3,'Night':4},default=5)
        .cast(pl.Int8)
        .alias('order')
    )
    .sort('order')
)
display(tod_stats)
# Out:
# shape: (4, 4)
# ┌─────────────┬─────────────────┬───────────────┬───────┐
# │ time_of_day ┆ median_duration ┆ session_count ┆ order │
# │ ---         ┆ ---             ┆ ---           ┆ ---   │
# │ str         ┆ f64             ┆ u32           ┆ i8    │
# ╞═════════════╪═════════════════╪═══════════════╪═══════╡
# │ Morning     ┆ 16.0            ┆ 64            ┆ 1     │
# │ Afternoon   ┆ 11.0            ┆ 38            ┆ 2     │
# │ Evening     ┆ 19.5            ┆ 38            ┆ 3     │
# │ Night       ┆ 14.5            ┆ 56            ┆ 4     │
# └─────────────┴─────────────────┴───────────────┴───────┘

# %%
fig_tod = px.box(
    tod_analytics.to_pandas(),
    x='time_of_day',
    y='duration_minutes',
    color='time_of_day',
    category_orders={'time_of_day':['Morning','Afternoon','Evening','Night']},
    title='Session Duration by Time of Day',
    labels={'duration_minutes':'Minutes','time_of_day':'Time of Day'},
    points='outliers'
)

fig_tod.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a14f62e5-3a7c-4d8b-a2ec-f4ced367ce88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a14f62e5-3a7c-4d8b-a2ec-f4ced367ce88")) {                    Plotly.newPlot(                        "a14f62e5-3a7c-4d8b-a2ec-f4ced367ce88",                        [{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Time of Day=%{x}\u003cbr\u003eMinutes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Morning","marker":{"color":"#636efa"},"name":"Morning","notched":false,"offsetgroup":"Morning","orientation":"v","showlegend":true,"x":["Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning","Morning"],"x0":" ","xaxis":"x","y":[22,3,17,9,17,21,7,18,18,10,15,29,9,19,27,22,4,1,26,15,11,30,8,27,7,9,5,26,13,24,27,4,44,26,4,20,24,16,9,8,16,16,11,1,11,16,11,5,23,18,2,29,60,30,25,3,13,24,2,18,18,29,27,16],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Time of Day=%{x}\u003cbr\u003eMinutes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afternoon","marker":{"color":"#EF553B"},"name":"Afternoon","notched":false,"offsetgroup":"Afternoon","orientation":"v","showlegend":true,"x":["Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon","Afternoon"],"x0":" ","xaxis":"x","y":[6,2,11,20,13,23,11,9,6,4,11,8,2,8,8,11,23,10,1,25,22,14,7,9,6,7,24,7,13,28,28,18,20,18,7,18,18,20],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Time of Day=%{x}\u003cbr\u003eMinutes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Evening","marker":{"color":"#00cc96"},"name":"Evening","notched":false,"offsetgroup":"Evening","orientation":"v","showlegend":true,"x":["Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening","Evening"],"x0":" ","xaxis":"x","y":[27,11,29,30,27,8,9,22,18,20,9,3,23,9,27,19,16,24,23,14,23,3,7,28,21,5,13,10,7,27,29,28,28,21,20,11,9,15],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"outliers","hovertemplate":"Time of Day=%{x}\u003cbr\u003eMinutes=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Night","marker":{"color":"#ab63fa"},"name":"Night","notched":false,"offsetgroup":"Night","orientation":"v","showlegend":true,"x":["Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Night","Nig ...
